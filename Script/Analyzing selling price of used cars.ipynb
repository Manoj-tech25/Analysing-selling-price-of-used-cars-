# %% [markdown]
# ## Import and read

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
dataset = pd.read_csv('archive/output.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  \
# 0           0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front
# 1           1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front
# 2           2  2  164         audi  gas  std  four        sedan  fwd  front
# 3           3  2  164         audi  gas  std  four        sedan  4wd  front
# 4           4  2    ?         audi  gas  std   two        sedan  fwd  front
#
#    ...  130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  ...  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  ...  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  ...  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  ...  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  ...  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 27 columns]

# %%
dataset=dataset.iloc[:,1:]

# %%
dataset
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
headers = ["symboling", "normalized-losses", "make", 
           "fuel-type", "aspiration","num-of-doors",
           "body-style","drive-wheels", "engine-location",
           "wheel-base","length", "width","height", "curb-weight",
           "engine-type","num-of-cylinders", "engine-size", 
           "fuel-system","bore","stroke", "compression-ratio",
           "horsepower", "peak-rpm","city-mpg","highway-mpg","price"]
dataset.columns=headers
dataset.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
dataset.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
dataset['city-mpg'] = 256/dataset['city-mpg']
dataset.rename(columns = {'city_mpg': "city-L / 100km"},inplace=True)

print(dataset.columns)
dataset.dtypes
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# ...

# %%
dataset.price.unique()
# Out:
# array(['16500', '13950', '17450', '15250', '17710', '18920', '23875', '?',
#        '16430', '16925', '20970', '21105', '24565', '30760', '41315',
#        '36880', '5151', '6295', '6575', '5572', '6377', '7957', '6229',
#        '6692', '7609', '8558', '8921', '12964', '6479', '6855', '5399',
#        '6529', '7129', '7295', '7895', '9095', '8845', '10295', '12945',
#        '10345', '6785', '11048', '32250', '35550', '36000', '5195',
#        '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#        '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#        '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#        '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#        '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#        '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#        '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
dataset=dataset[dataset.price != '?']

# %%
dataset['price']=dataset['price'].astype(int)
dataset.dtypes
# Out:
# C:\Users\Manojkumar\AppData\Local\Temp\ipykernel_18480\2264021822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['price']=dataset['price'].astype(int)
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# ...

# %%
dataset['length']=dataset['length']/dataset['length'].max()
dataset['height']=dataset['height']/dataset['height'].max()
dataset['width']=dataset['width']/dataset['width'].max()
# binning- grouping values
bins = np.linspace(min(dataset['price']), max(dataset['price']), 4) 
group_names = ['Low', 'Medium', 'High']
dataset['price-binned'] = pd.cut(dataset['price'], bins, 
                              labels = group_names, 
                              include_lowest = True)
print(dataset['price-binned'])
plt.hist(dataset['price-binned'])
plt.show()
# Out:
# 0         Low
# 1         Low
# 2         Low
# 3         Low
# 4         Low
#         ...
# 199       Low
# 200    Medium
# 201    Medium
# 202    Medium
# 203    Medium
# Name: price-binned, Length: 200, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']
# C:\Users\Manojkumar\AppData\Local\Temp\ipykernel_18480\3313863225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['length']=dataset['length']/dataset['length'].max()
# C:\Users\Manojkumar\AppData\Local\Temp\ipykernel_18480\3313863225.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# categorical to numerical variables
pd.get_dummies(dataset['fuel-type']).head()

# descriptive analysis
# NaN are skipped
dataset.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.830000   98.848000    0.837232    0.915250    0.899523
# std      1.248557    6.038261    0.059333    0.029207    0.040610
# min     -2.000000   86.600000    0.678039    0.837500    0.799331
# 25%      0.000000   94.500000    0.800937    0.891319    0.869565
# 50%      1.000000   97.000000    0.832292    0.909722    0.904682
# 75%      2.000000  102.400000    0.881788    0.926042    0.928512
# max      3.000000  120.900000    1.000000    1.000000    1.000000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg  \
# count   200.000000   200.000000         200.000000  200.000000   200.000000
# mean   2555.705000   126.860000          10.170100   25.200000    30.705000
# std     518.594552    41.650501           4.014163    6.432487     6.827227
# ...

# %%
# examples of box plot
plt.boxplot(dataset['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d6caa6ca70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d6caa6cfb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d6c696f770>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d6caa6d5e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d6caa6d8e0>],
#  'means': []}

# %%
# by using seaborn
sns.boxplot(x ='drive-wheels', y ='price', data = dataset)

# Predicting price based on engine size
# Known on x and predictable on y
plt.scatter(dataset['engine-size'], dataset['price'])
plt.title('Scatterplot of Enginesize vs Price')
plt.xlabel('Engine size')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
# Grouping Data
test = dataset[['drive-wheels', 'body-style', 'price']]
data_grp = test.groupby(['drive-wheels', 'body-style'], 
                         as_index = False).mean()

data_grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  26563.250000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
# pivot method
data_pivot = data_grp.pivot(index = 'drive-wheels',
                            columns = 'body-style')
data_pivot

# heatmap for visualizing data
plt.pcolor(data_pivot, cmap ='RdBu')
plt.colorbar()
plt.show()

# %%
# Analysis of Variance- ANOVA
# returns f-test and p-value
# f-test = variance between sample group means divided by 
# variation within sample group
# p-value = confidence degree
data_annova = dataset[['make', 'price']]
grouped_annova = data_annova.groupby(['make'])
annova_results_l = sp.stats.f_oneway(
                             grouped_annova.get_group('honda')['price'],
                             grouped_annova.get_group('subaru')['price']
                                    )
print(annova_results_l)

# strong corealtion between a categorical variable
# if annova test gives large f-test and small p-value

# Correlation- measures dependency, not causation
sns.regplot(x ='engine-size', y ='price', data = dataset)
plt.ylim(0, )
# Out:
# F_onewayResult(statistic=np.float64(0.19744030127462606), pvalue=np.float64(0.6609478240622193))
# C:\Users\Manojkumar\AppData\Local\Temp\ipykernel_18480\2812729353.py:9: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   grouped_annova.get_group('honda')['price'],
# C:\Users\Manojkumar\AppData\Local\Temp\ipykernel_18480\2812729353.py:10: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   grouped_annova.get_group('subaru')['price']
# (0.0, 53294.61357383631)
